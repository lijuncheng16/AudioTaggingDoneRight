# %%
import torch
import numpy as np

import dataloader

import os
import subprocess
import socket
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="3"

# %%
curr_node = socket.gethostname().split('.')[0]
batcmd=f"squeue -u billyli | grep {curr_node}"
curr_slurm = subprocess.check_output(batcmd, shell=True, text=True)
slurm_id = curr_slurm.strip().split(' ')[0]
local = f"/local/slurm-{slurm_id}/local/audio/data"

# %%
print(local)
# Out:
# /local/slurm-7047405/local/audio/data

# %% [markdown]
# # set skip_norm as True only when you are computing the normalization stats

# %% [raw]
# datafiles/audioset_bal_unbal_train_data.json

# %%
audio_conf = {'num_mel_bins': 128, 'target_length': 1028, 'freqm': 36, 'timem': 192, 'mixup': 0.3, 'skip_norm': True, 'mode': 'train', 'dataset': 'audioset'}
train_loader = torch.utils.data.DataLoader(dataloader.AudiosetDataset(os.path.join(local,'datafiles/audioset_bal_train_data.json'), label_csv=os.path.join(local, 'class_labels_indices.csv'),
                                audio_conf=audio_conf), batch_size=100, shuffle=False, num_workers=8, pin_memory=True)
# Out:
# ---------------the train dataloader---------------
# now using following mask: 36 freq, 192 time
# now using mix-up with rate 0.300000
# now process audioset
# now skip normalization (use it ONLY when you are computing the normalization stats).
# number of classes is 527

# %%
#128 x 1024 features:
# freqm 48 timem 192 mixup 0.5: -3.3458831 4.1563106
# freqm 36 timem 192 mixup 0.5: -3.5172966 4.1748486
# freqm 36 timem 192 mixup 0.3: -3.6788461 4.3739743

#64 x 400 features:
# freqm 24 timem 75 mixup 0.5: -24.584522, 37.10214
# freqm 12 timem 75 mixup 0.5: -27.248297 37.681698
# freqm 12 timem 75 mixup 0.3: -29.072655 40.71728
# freqm 12 timem 60 mixup 0.5: -27.712713 37.934616
# freqm 12 timem 60 mixup 0.3: -29.686901 40.898224
# freqm 12 timem 60 mixup 0.2: -30.733978 42.267876
# freqm 12 timem 56 mixup 0.4: -28.799559 39.34941
# freqm 12 timem 56 mixup 0.25: -30.333525 41.43794
# freqm 10 timem 50 mixup 0.3: -30.68206 41.202892
# freqm 10 timem 50 mixup 0.2: -31.451344 42.354965
# freqm 6 timem 25 mixup 0.5: -30.446014 38.751587
# freqm 6 timem 25 mixup 0.3: -32.60682 41.53026
# freqm 6 timem 25 mixup 0.2: -33.632145 42.845398
# freqm 6 timem 25 mixup 0.1: -34.673824 44.153343
# freqm 0 timem 0 mixup 0: -38.193954 45.802143

# %%
mean=[]
std=[]
for i, (audio_input, labels) in enumerate(train_loader):
    cur_mean = torch.mean(audio_input)
    cur_std = torch.std(audio_input)
    mean.append(cur_mean)
    std.append(cur_std)
    print(i, cur_mean, cur_std)
print(np.mean(mean), np.mean(std))
# Out:
# 0 tensor(-3.5016) tensor(4.3141)
# 1 tensor(-3.5525) tensor(4.1721)
# 2 tensor(-3.4500) tensor(4.1703)
# 3 tensor(-3.4455) tensor(4.4160)
# 4 tensor(-3.3199) tensor(4.2381)
# 5 tensor(-3.4541) tensor(4.1239)
# 6 tensor(-3.5649) tensor(4.2775)
# 7 tensor(-3.4195) tensor(4.2986)
# 8 tensor(-3.5836) tensor(4.1853)
# 9 tensor(-3.7443) tensor(4.4824)
# 10 tensor(-3.3842) tensor(4.2118)
# 11 tensor(-3.4670) tensor(4.3334)
# 12 tensor(-3.6244) tensor(4.3221)
# 13 tensor(-3.7645) tensor(4.4890)
# 14 tensor(-3.6920) tensor(4.4397)
# 15 tensor(-3.6705) tensor(4.2486)
# 16 tensor(-3.7720) tensor(4.3390)
# 17 tensor(-3.9165) tensor(4.5358)
# 18 tensor(-3.3333) tensor(3.9885)
# 19 tensor(-3.5592) tensor(4.3173)
# 20 tensor(-3.5942) tensor(4.2111)
# 21 tensor(-3.7043) tensor(4.4570)
# 22 tensor(-3.6371) tensor(4.2238)
# 23 tensor(-3.6243) tensor(4.2880)
# 24 tensor(-3.6669) tensor(4.4014)
# 25 tensor(-3.7926) tensor(4.4947)
# 26 tensor(-3.5585) tensor(4.4786)
# 27 tensor(-3.8874) tensor(4.5720)
# 28 tensor(-3.1850) tensor(3.8988)
# 29 tensor(-3.6998) tensor(4.5155)
# 30 tensor(-3.7403) tensor(4.2104)
# 31 tensor(-3.7969) tensor(4.3663)
# 32 tensor(-3.6783) tensor(4.3934)
# 33 tensor(-3.7595) tensor(4.2897)
# 34 tensor(-3.3539) tensor(4.1781)
# 35 tensor(-3.7855) tensor(4.3754)
# 36 tensor(-3.8756) tensor(4.4264)
# 37 tensor(-3.6043) tensor(4.3078)
# 38 tensor(-3.6572) tensor(4.3361)
# 39 tensor(-3.7607) tensor(4.3621)
# 40 tensor(-3.4688) tensor(4.3751)
# 41 tensor(-3.3358) tensor(4.1046)
# 42 tensor(-3.4656) tensor(4.2872)
# 43 tensor(-3.8531) tensor(4.5127)
# 44 tensor(-3.1854) tensor(3.9654)
# 45 tensor(-3.7391) tensor(4.3060)
# 46 tensor(-3.6818) tensor(4.2515)
# 47 tensor(-3.6863) tensor(4.4438)
# 48 tensor(-3.4343) tensor(4.1544)
# 49 tensor(-3.8711) tensor(4.3971)
# 50 tensor(-3.9824) tensor(4.5679)
# 51 tensor(-3.3263) tensor(4.1993)
# 52 tensor(-3.6006) tensor(4.3365)
# 53 tensor(-3.7706) tensor(4.5193)
# 54 tensor(-3.6853) tensor(4.3386)
# 55 tensor(-3.6470) tensor(4.3228)
# 56 tensor(-3.3787) tensor(4.4084)
# 57 tensor(-3.6459) tensor(4.3948)
# 58 tensor(-3.6091) tensor(4.1755)
# 59 tensor(-3.9050) tensor(4.4210)
# 60 tensor(-3.7478) tensor(4.5239)
# 61 tensor(-3.8359) tensor(4.3769)
# 62 tensor(-3.5697) tensor(4.2470)
# 63 tensor(-3.6092) tensor(4.0298)
# 64 tensor(-3.5379) tensor(4.1476)
# 65 tensor(-3.8555) tensor(4.4681)
# 66 tensor(-3.4151) tensor(4.1402)
# 67 tensor(-3.7607) tensor(4.4362)
# 68 tensor(-3.5662) tensor(4.3234)
# 69 tensor(-3.4151) tensor(4.2124)
# 70 tensor(-3.8643) tensor(4.4157)
# 71 tensor(-4.1787) tensor(4.6324)
# 72 tensor(-3.5958) tensor(4.3461)
# 73 tensor(-3.4335) tensor(4.3195)
# 74 tensor(-3.7584) tensor(4.3146)
# 75 tensor(-3.5327) tensor(4.4354)
# 76 tensor(-3.6797) tensor(4.2983)
# 77 tensor(-3.5036) tensor(4.2438)
# 78 tensor(-3.5567) tensor(4.4229)
# 79 tensor(-3.6299) tensor(4.5248)
# 80 tensor(-3.7847) tensor(4.5839)
# 81 tensor(-4.1354) tensor(4.7847)
# 82 tensor(-3.7575) tensor(4.5362)
# 83 tensor(-3.6808) tensor(4.2855)
# 84 tensor(-4.0630) tensor(4.7409)
# 85 tensor(-3.8183) tensor(4.3561)
# 86 tensor(-4.0327) tensor(4.5747)
# 87 tensor(-3.8691) tensor(4.6342)
# 88 tensor(-3.6266) tensor(4.2247)
# 89 tensor(-3.5563) tensor(4.1299)
# 90 tensor(-3.8568) tensor(4.2794)
# 91 tensor(-3.9011) tensor(4.4295)
# 92 tensor(-3.6113) tensor(4.4089)
# 93 tensor(-3.6360) tensor(4.2764)
# 94 tensor(-3.8521) tensor(4.4411)
# 95 tensor(-3.4231) tensor(4.3478)
# 96 tensor(-3.6258) tensor(4.2119)
# 97 tensor(-3.4489) tensor(4.2813)
# 98 tensor(-4.0380) tensor(4.6038)
# 99 tensor(-3.4335) tensor(4.2426)
# 100 tensor(-3.2242) tensor(4.1088)
# 101 tensor(-3.4429) tensor(4.1817)
# 102 tensor(-3.8852) tensor(4.4743)
# 103 tensor(-3.7202) tensor(4.5879)
# 104 tensor(-4.0521) tensor(4.5685)
# 105 tensor(-3.5544) tensor(4.0996)
# 106 tensor(-3.8053) tensor(4.3470)
# 107 tensor(-3.7020) tensor(4.5313)
# 108 tensor(-3.6297) tensor(4.2906)
# 109 tensor(-3.8570) tensor(4.3124)
# 110 tensor(-3.1419) tensor(4.0268)
# 111 tensor(-4.2063) tensor(4.6119)
# 112 tensor(-3.6276) tensor(4.5254)
# 113 tensor(-3.7368) tensor(4.3494)
# 114 tensor(-3.4910) tensor(4.1999)
# 115 tensor(-4.0730) tensor(4.4209)
# 116 tensor(-3.9258) tensor(4.4782)
# 117 tensor(-3.8243) tensor(4.5088)
# 118 tensor(-3.5933) tensor(4.2491)
# 119 tensor(-3.4435) tensor(4.3118)
# 120 tensor(-3.4552) tensor(4.4031)
# 121 tensor(-3.5693) tensor(4.4384)
# 122 tensor(-3.3571) tensor(4.2103)
# 123 tensor(-3.2335) tensor(4.1829)
# 124 tensor(-3.6371) tensor(4.4916)
# 125 tensor(-3.4073) tensor(4.2600)
# 126 tensor(-3.8600) tensor(4.5021)
# 127 tensor(-3.6550) tensor(4.3832)
# 128 tensor(-3.5645) tensor(4.6013)
# 129 tensor(-3.4506) tensor(4.1877)
# 130 tensor(-3.8578) tensor(4.5824)
# 131 tensor(-3.8737) tensor(4.5003)
# 132 tensor(-4.1284) tensor(4.6646)
# 133 tensor(-3.4773) tensor(4.4299)
# 134 tensor(-3.6574) tensor(4.3114)
# 135 tensor(-3.7232) tensor(4.4291)
# 136 tensor(-3.6774) tensor(4.4441)
# 137 tensor(-4.0668) tensor(4.4087)
# 138 tensor(-3.6207) tensor(4.4385)
# 139 tensor(-3.8025) tensor(4.4549)
# 140 tensor(-3.8143) tensor(4.6442)
# 141 tensor(-3.2253) tensor(4.2074)
# 142 tensor(-3.5609) tensor(4.2334)
# 143 tensor(-3.6089) tensor(4.3552)
# 144 tensor(-3.7843) tensor(4.4441)
# 145 tensor(-3.7341) tensor(4.4041)
# 146 tensor(-3.7328) tensor(4.3364)
# 147 tensor(-3.5817) tensor(4.2186)
# 148 tensor(-3.4844) tensor(4.3104)
# 149 tensor(-3.3493) tensor(4.0273)
# 150 tensor(-3.7283) tensor(4.5361)
# 151 tensor(-3.8217) tensor(4.2842)
# 152 tensor(-3.6305) tensor(4.1390)
# 153 tensor(-3.7734) tensor(4.6165)
# 154 tensor(-3.5295) tensor(4.1742)
# 155 tensor(-3.6935) tensor(4.3623)
# 156 tensor(-3.2131) tensor(4.1884)
# 157 tensor(-3.6954) tensor(4.2920)
# 158 tensor(-4.0792) tensor(4.4971)
# 159 tensor(-3.8064) tensor(4.3873)
# 160 tensor(-4.0753) tensor(4.5809)
# 161 tensor(-3.9509) tensor(4.5409)
# 162 tensor(-3.4728) tensor(4.1439)
# 163 tensor(-3.3416) tensor(4.2000)
# 164 tensor(-3.8053) tensor(4.5472)
# 165 tensor(-3.5502) tensor(4.2526)
# 166 tensor(-3.5654) tensor(4.1779)
# 167 tensor(-4.0710) tensor(4.5524)
# 168 tensor(-3.6208) tensor(4.3569)
# 169 tensor(-3.7855) tensor(4.3217)
# 170 tensor(-4.1842) tensor(4.6272)
# 171 tensor(-3.9369) tensor(4.4456)
# 172 tensor(-4.1929) tensor(4.8045)
# 173 tensor(-3.7720) tensor(4.4337)
# 174 tensor(-3.4910) tensor(4.2820)
# 175 tensor(-3.6179) tensor(4.1797)
# 176 tensor(-3.5149) tensor(4.3153)
# 177 tensor(-3.7388) tensor(4.5113)
# 178 tensor(-3.3534) tensor(4.1433)
# 179 tensor(-3.4894) tensor(4.4656)
# 180 tensor(-3.4654) tensor(4.2222)
# 181 tensor(-3.7940) tensor(4.3242)
# 182 tensor(-3.8694) tensor(4.4302)
# 183 tensor(-3.4761) tensor(4.1939)
# 184 tensor(-3.2837) tensor(4.1830)
# 185 tensor(-3.8594) tensor(4.4875)
# 186 tensor(-3.5449) tensor(4.2478)
# 187 tensor(-3.7351) tensor(4.2343)
# 188 tensor(-3.7848) tensor(4.4047)
# 189 tensor(-3.8987) tensor(4.6382)
# 190 tensor(-3.6604) tensor(4.6039)
# 191 tensor(-3.6350) tensor(4.4005)
# 192 tensor(-3.6000) tensor(4.5024)
# 193 tensor(-3.4244) tensor(4.1782)
# 194 tensor(-3.7820) tensor(4.4551)
# 195 tensor(-4.0065) tensor(4.6777)
# 196 tensor(-4.0384) tensor(4.6734)
# 197 tensor(-3.3602) tensor(4.2352)
# 198 tensor(-3.8139) tensor(4.4655)
# 199 tensor(-3.2707) tensor(4.2642)
# 200 tensor(-3.6996) tensor(4.5971)
# 201 tensor(-4.0444) tensor(4.6740)
# 202 tensor(-3.5275) tensor(4.1856)
# 203 tensor(-3.6487) tensor(4.2732)
# 204 tensor(-3.7607) tensor(4.6422)
# 205 tensor(-3.7371) tensor(4.2819)
# 206 tensor(-3.8880) tensor(4.4919)
# 207 tensor(-3.4448) tensor(4.1376)
# 208 tensor(-3.7971) tensor(4.5757)
# 209 tensor(-3.8688) tensor(4.4734)
# 210 tensor(-3.4292) tensor(4.2112)
# 211 tensor(-3.8580) tensor(4.4007)
# 212 tensor(-3.8605) tensor(4.5160)
# 213 tensor(-3.4874) tensor(4.3245)
# 214 tensor(-3.8035) tensor(4.3121)
# 215 tensor(-3.8770) tensor(4.2977)
# 216 tensor(-3.2237) tensor(3.9255)
# 217 tensor(-3.8071) tensor(4.4274)
# -3.6674564 4.362492
